# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import requests
from congress_scrape import fetch_hearing

# %%
# url = "https://www.congress.gov/event/117th-congress/senate-event/LC74170/text"
# rec = fetch_hearing(url, headless=False, timeout_s=300,
#                     save_txt="hearing.txt",
#                     save_json="hearing.json")
# rec.title, rec.date_text, rec.date_iso, rec.committee
# # rec.transcript  # long

url = 'https://www.govinfo.gov/browse/committee'

r = requests.get(url)
r.status_code
# Out:
# 200

# %%
bs = BeautifulSoup(r.content)
bs.get
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">
# <head>
# <meta charset="utf-8"/>
# <meta content="Browse a list of available Congressional Committee document collections." name="description"/>
# <link href="https://www.govinfo.gov/browse/committee" rel="canonical"/>
# <meta content="GovInfo" property="og:site_name"/>
# <meta content="Government" property="og:type"/>
# <meta content="https://www.govinfo.gov/browse/committee" property="og:url"/>
# <meta content="Browse by Committee" property="og:title"/>
# ...
