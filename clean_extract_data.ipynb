# %% [markdown]
# Imports

# %%
import pandas as pd
import helper_funcs

# %%
sessions = [119, 118] #, 117, 116, 115, 114, 113, 112, 111, 110, 109, 108, 107, 106, 105, 104]

# %%
for session in sessions:
    df = pd.read_csv(f"data/session_{session}.csv")

    #Clean text
    df['text'] = df['text'].apply(helper_funcs.extract_main_text)

    #get date
    df['date'] = df['text'].apply(helper_funcs.get_date)
    df['month'] = df['date'].apply(helper_funcs.get_month)

    #get heading
    df['title'] = df['text'].apply(helper_funcs.extract_hearing_title)

    #reorder columns
    cols = "details_url,text_url,session,text,date,title".split(",")
    df = df[[c for c in df.columns if c != "text"] + ["text"]]

    df.to_csv(f"data/cleaned/session_{session}_cleaned.csv", index=False)
    print(f"saved session {session}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 9
#       7 #get date
#       8 df['date'] = df['text'].apply(helper_funcs.get_date)
# ----> 9 df['month'] = df['date'].apply(helper_funcs.get_month)
#      11 #get heading
#      12 df['title'] = df['text'].apply(helper_funcs.extract_hearing_title)
#
# File c:\Users\lmikk\personalFiles\School\fall2025\stat386\senate-hearings\.venv\Lib\site-packages\pandas\core\series.py:4943, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4808 def apply(
#    4809     self,
#    4810     func: AggFuncType,
#    (...)   4815     **kwargs,
#    4816 ) -> DataFrame | Series:
#    4817     """
#    4818     Invoke function on values of Series.
#    4819
#    (...)   4934     dtype: float64
#    4935     """
#    4936     return SeriesApply(
#    4937         self,
#    4938         func,
#    4939         convert_dtype=convert_dtype,
#    4940         by_row=by_row,
#    4941         args=args,
#    4942         kwargs=kwargs,
# -> 4943     ).apply()
#
# File c:\Users\lmikk\personalFiles\School\fall2025\stat386\senate-hearings\.venv\Lib\site-packages\pandas\core\apply.py:1422, in SeriesApply.apply(self)
#    1419     return self.apply_compat()
#    1421 # self.func is Callable
# -> 1422 return self.apply_standard()
#
# File c:\Users\lmikk\personalFiles\School\fall2025\stat386\senate-hearings\.venv\Lib\site-packages\pandas\core\apply.py:1502, in SeriesApply.apply_standard(self)
#    1496 # row-wise access
#    1497 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1498 # we need to give `na_action="ignore"` for categorical data.
#    1499 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1500 #  Categorical (GH51645).
#    1501 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1502 mapped = obj._map_values(
#    1503     mapper=curried, na_action=action, convert=self.convert_dtype
#    1504 )
#    1506 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1507     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1508     #  See also GH#25959 regarding EA support
#    1509     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\lmikk\personalFiles\School\fall2025\stat386\senate-hearings\.venv\Lib\site-packages\pandas\core\base.py:925, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     922 if isinstance(arr, ExtensionArray):
#     923     return arr.map(mapper, na_action=na_action)
# --> 925 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\lmikk\personalFiles\School\fall2025\stat386\senate-hearings\.venv\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File pandas/_libs/lib.pyx:2999, in pandas._libs.lib.map_infer()
#
# File c:\Users\lmikk\personalFiles\School\fall2025\stat386\senate-hearings\helper_funcs.py:331, in get_month(date)
#     330 def get_month(date):
# --> 331     if "January" in date:
#     332         return 1
#     333     elif "February" in date:
#
# TypeError: argument of type 'NoneType' is not a container or iterable

# %%
session = 119
df = pd.read_csv(f"data/cleaned/session_{session}_cleaned.csv")
df
# Out:
#                                           details_url  \
# 0   https://www.govinfo.gov/content/pkg/CHRG-119sh...
# 1   https://www.govinfo.gov/content/pkg/CHRG-119sh...
# 2   https://www.govinfo.gov/content/pkg/CHRG-119sh...
# 3   https://www.govinfo.gov/content/pkg/CHRG-119sh...
# 4   https://www.govinfo.gov/content/pkg/CHRG-119sh...
# ..                                                ...
# 84  https://www.govinfo.gov/content/pkg/CHRG-119sh...
# 85  https://www.govinfo.gov/content/pkg/CHRG-119sh...
# 86  https://www.govinfo.gov/content/pkg/CHRG-119sh...
# 87  https://www.govinfo.gov/content/pkg/CHRG-119sh...
# 88  https://www.govinfo.gov/content/pkg/CHRG-119sh...
#
#                                              text_url  session  \
# 0   https://www.govinfo.gov/content/pkg/CHRG-119sh...    119.0
# 1   https://www.govinfo.gov/content/pkg/CHRG-119sh...    119.0
# 2   https://www.govinfo.gov/content/pkg/CHRG-119sh...    119.0
# 3   https://www.govinfo.gov/content/pkg/CHRG-119sh...    119.0
# 4   https://www.govinfo.gov/content/pkg/CHRG-119sh...    119.0
# ..                                                ...      ...
# 84  https://www.govinfo.gov/content/pkg/CHRG-119sh...    119.0
# 85  https://www.govinfo.gov/content/pkg/CHRG-119sh...    119.0
# 86  https://www.govinfo.gov/content/pkg/CHRG-119sh...    119.0
# 87  https://www.govinfo.gov/content/pkg/CHRG-119sh...    119.0
# 88  https://www.govinfo.gov/content/pkg/CHRG-119sh...    119.0
#
#                  date                                              title  \
# 0       July 29, 2025  PERSPECTIVES ON REAUTHORIZATION OF THE \n U.S....
# 1       July 23, 2025  NOMINATION OF RICHARD FORDYCE TO BE \n UNDER S...
# 2       July 15, 2025  STAKEHOLDER PERSPECTIVES ON FEDERAL \n OVERSIG...
# 3       June 10, 2025  NOMINATION OF THE HONORABLE BRIAN \n QUINTENZ,...
# 4        June 3, 2025  NOMINATION OF MICHAEL BOREN TO BE UNDER SECRET...
# ..                ...                                                ...
# 84  February 26, 2025           LEGISLATIVE PRESENTATION OF THE AMERICAN
# 85  February 25, 2025                        LEGISLATIVE PRESENTATION OF
# 86  February 19, 2025  NOMINATION OF THE HONORABLE\n PAUL LAWRENCE TO...
# 87   January 28, 2025              EXAMINING VA'S COMMUNITY CARE PROGRAM
# 88   January 21, 2025  NOMINATION OF THE HONORABLE\n DOUGLAS A. COLLI...
#
#                                                  text
# 0   S. Hrg. 119-131\n\n PERSPECTIVES ON REAUTHORIZ...
# 1   S. Hrg. 119-127\n\n NOMINATION OF RICHARD FORD...
# 2   S. Hrg. 119-115\n\n STAKEHOLDER PERSPECTIVES O...
# 3   S. Hrg. 119-99\n\n NOMINATION OF THE HONORABLE...
# 4   ______\n\n S. Hrg. 119-98\n \n NOMINATION OF M...
# ..                                                ...
# 84  S. Hrg. 119-15\n\n LEGISLATIVE PRESENTATION OF...
# 85  S. Hrg. 119-14\n\n LEGISLATIVE PRESENTATION OF...
# 86  S. Hrg. 119-13\n\n NOMINATION OF THE HONORABLE...
# 87  S. Hrg. 119-7\n\n PROTECTING VETERAN CHOICE:\n...
# 88  S. Hrg. 119-6\n\n NOMINATION OF THE HONORABLE\...
#
# [89 rows x 6 columns]
