# %% [markdown]
# Imports

# %%
from bs4 import BeautifulSoup
import requests
import time
import re
import pandas as pd
from helper_funcs import extract_hearing_links
import glob

# %% [markdown]
# Request and get soup for each file

# %%
all_dfs = []
list_of_html_files = glob.glob("senate_html/*.html")

for file in list_of_html_files:
    with open(file, "r", encoding="utf-8") as f:
        html_text = f.read()

    df = extract_hearing_links(html_text)
    all_dfs.append(df)

# Combine into one DataFrame
final_df = pd.concat(all_dfs, ignore_index=True)
print(final_df)
# Out:
# No 'Congressional Hearings' span found
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 8
#       5     with open(file, "r", encoding="utf-8") as f:
#       6         html_text = f.read()
# ----> 8     df = extract_hearing_links(html_text)
#       9     all_dfs.append(df)
#      11 # Combine into one DataFrame
#
# File c:\Users\lmikk\personalFiles\School\fall2025\stat386\senate-hearings\helper_funcs.py:230, in extract_hearing_links(html)
#     229 def extract_hearing_links(html):
# --> 230     soup = BeautifulSoup(html, "html.parser")
#     231     rows = []
#     233     # 1. Find the "Congressional Hearings" panel
#
# File c:\Users\lmikk\personalFiles\School\fall2025\stat386\senate-hearings\.venv\Lib\site-packages\bs4\__init__.py:476, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     474 self.builder.initialize_soup(self)
#     475 try:
# --> 476     self._feed()
#     477     success = True
#     478     break
#
# File c:\Users\lmikk\personalFiles\School\fall2025\stat386\senate-hearings\.venv\Lib\site-packages\bs4\__init__.py:661, in BeautifulSoup._feed(self)
#     658 self.builder.reset()
#     660 if self.markup is not None:
# --> 661     self.builder.feed(self.markup)
#     662 # Close out any unfinished strings and close all the open tags.
#     663 self.endData()
#
# File c:\Users\lmikk\personalFiles\School\fall2025\stat386\senate-hearings\.venv\Lib\site-packages\bs4\builder\_htmlparser.py:467, in HTMLParserTreeBuilder.feed(self, markup)
#     464 parser = BeautifulSoupHTMLParser(self.soup, *args, **kwargs)
#     466 try:
# --> 467     parser.feed(markup)
#     468     parser.close()
#     469 except AssertionError as e:
#     470     # html.parser raises AssertionError in rare cases to
#     471     # indicate a fatal problem with the markup, especially
#     472     # when there's an error in the doctype declaration.
#
# File C:\Python314\Lib\html\parser.py:160, in HTMLParser.feed(self, data)
#     154 r"""Feed data to the parser.
#     155
#     156 Call this as often as you want, with as little or as much text
#     157 as you want (may include '\n').
#     158 """
#     159 self.rawdata = self.rawdata + data
# --> 160 self.goahead(0)
#
# File C:\Python314\Lib\html\parser.py:240, in HTMLParser.goahead(self, end)
#     238 if startswith('<', i):
#     239     if starttagopen.match(rawdata, i): # < + letter
# --> 240         k = self.parse_starttag(i)
#     241     elif startswith("</", i):
#     242         k = self.parse_endtag(i)
#
# File C:\Python314\Lib\html\parser.py:446, in HTMLParser.parse_starttag(self, i)
#     444     self.handle_startendtag(tag, attrs)
#     445 else:
# --> 446     self.handle_starttag(tag, attrs)
#     447     if tag in self.CDATA_CONTENT_ELEMENTS:
#     448         self.set_cdata_mode(tag)
#
# File c:\Users\lmikk\personalFiles\School\fall2025\stat386\senate-hearings\.venv\Lib\site-packages\bs4\builder\_htmlparser.py:182, in BeautifulSoupHTMLParser.handle_starttag(self, tag, attrs, handle_empty_element)
#     180 else:
#     181     sourceline = sourcepos = None
# --> 182 tagObj = self.soup.handle_starttag(
#     183     tag, None, None, attr_dict, sourceline=sourceline, sourcepos=sourcepos
#     184 )
#     185 if tagObj is not None and tagObj.is_empty_element and handle_empty_element:
#     186     # Unlike other parsers, html.parser doesn't send separate end tag
#     187     # events for empty-element tags. (It's handled in
#    (...)    193     # don't want handle_endtag() to cross off any previous end
#     194     # events for tags of this name.
#     195     self.handle_endtag(tag, check_already_closed=False)
#
# File c:\Users\lmikk\personalFiles\School\fall2025\stat386\senate-hearings\.venv\Lib\site-packages\bs4\__init__.py:1035, in BeautifulSoup.handle_starttag(self, name, namespace, nsprefix, attrs, sourceline, sourcepos, namespaces)
#    1032 # Assume that this is either Tag or a subclass of Tag. If not,
#    1033 # the user brought type-unsafety upon themselves.
#    1034 tag_class = cast(Type[Tag], tag_class)
# -> 1035 tag = tag_class(
#    1036     self,
#    1037     self.builder,
#    1038     name,
#    1039     namespace,
#    1040     nsprefix,
#    1041     attrs,
#    1042     self.currentTag,
#    1043     self._most_recent_element,
#    1044     sourceline=sourceline,
#    1045     sourcepos=sourcepos,
#    1046     namespaces=namespaces,
#    1047 )
#    1048 if tag is None:
#    1049     return tag
#
# File c:\Users\lmikk\personalFiles\School\fall2025\stat386\senate-hearings\.venv\Lib\site-packages\bs4\element.py:1873, in Tag.__init__(self, parser, builder, name, namespace, prefix, attrs, parent, previous, is_xml, sourceline, sourcepos, can_be_empty_element, cdata_list_attributes, preserve_whitespace_tags, interesting_string_types, namespaces)
#    1871 else:
#    1872     if builder is not None and builder.cdata_list_attributes:
# -> 1873         self.attrs = builder._replace_cdata_list_attribute_values(
#    1874             self.name, attrs
#    1875         )
#    1876     else:
#    1877         self.attrs = attr_dict_class()
#
# File c:\Users\lmikk\personalFiles\School\fall2025\stat386\senate-hearings\.venv\Lib\site-packages\bs4\builder\__init__.py:382, in TreeBuilder._replace_cdata_list_attribute_values(self, tag_name, attrs)
#     371     """Set up any substitutions that will need to be performed on
#     372     a `Tag` when it's output as a string.
#     373
#    (...)    378     :meta private:
#     379     """
#     380     return False
# --> 382 def _replace_cdata_list_attribute_values(
#     383     self, tag_name: str, attrs: _RawOrProcessedAttributeValues
#     384 ) -> _AttributeValues:
#     385     """When an attribute value is associated with a tag that can
#     386     have multiple values for that attribute, convert the string
#     387     value to a list of strings.
#    (...)    396     :return: The modified dictionary that was originally passed in.
#     397     """
#     399     # First, cast the attrs dict to _AttributeValues. This might
#     400     # not be accurate yet, but it will be by the time this method
#     401     # returns.
#
# KeyboardInterrupt:

# %%
final_df.to_csv("senate_data.csv", index=False)
